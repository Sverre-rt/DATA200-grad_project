# %%
import pandas as pd
import seaborn as sns

# %%
import glob
from zipfile import ZipFile

def init_dataframe_from_zip(path, index_col):
    df_master = pd.DataFrame()
    flag = False
    files_in_folder = glob.glob(path)
    for filename in files_in_folder:    
        zip_file = ZipFile(filename)
        for text_file in zip_file.infolist():
            if text_file.filename.endswith('.csv'):
                df = pd.read_csv(zip_file.open(text_file.filename),header=0,index_col=[index_col])
                if not flag:
                    df_master = df
                    flag = True
                else:
                    df_master = pd.concat([df_master, df])
                
    return df_master

csse_covid_19_daily_reports_us = init_dataframe_from_zip(r'**csv_files/csse_covid_19_daily_reports_us.zip', 'UID')
#display(csse_covid_19_daily_reports_us)

# %%
df = pd.read_csv('csv_files/cdc_death_counts_by_sex_age_state.zip',header=0)
df.head(40)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4,5,9,10,11,12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             0           1           2         3     4      5              6   \
# 0   Data As Of  Start Date    End Date     Group  Year  Month          State
# 1   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 2   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 3   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 4   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 5   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 6   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 7   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 8   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 9   03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 10  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 11  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 12  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 13  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 14  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 15  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 16  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 17  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 18  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 19  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 20  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 21  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 22  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 23  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 24  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 25  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 26  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 27  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 28  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 29  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 30  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 31  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 32  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 33  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 34  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 35  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 36  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 37  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 38  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
# 39  03/23/2022  01/01/2020  03/19/2022  By Total   NaN    NaN  United States
#
#            7                  8                9             10  \
# 0         Sex          Age Group  COVID-19 Deaths  Total Deaths
# 1   All Sexes           All Ages           974282       7520550
# 2   All Sexes       Under 1 year              242         41777
# 3   All Sexes         0-17 years              933         74176
# 4   All Sexes          1-4 years              113          7791
# 5   All Sexes         5-14 years              296         12438
# 6   All Sexes        15-24 years             2545         79772
# 7   All Sexes        18-29 years             6044        140833
# 8   All Sexes        25-34 years            10803        168507
# 9   All Sexes        30-39 years            17609        208720
# 10  All Sexes        35-44 years            26952        249728
# 11  All Sexes        40-49 years            41975        313219
# 12  All Sexes        45-54 years            65096        443858
# 13  All Sexes        50-64 years           182663       1271909
# 14  All Sexes        55-64 years           143177       1004986
# 15  All Sexes        65-74 years           223949       1538289
# 16  All Sexes        75-84 years           251202       1823273
# 17  All Sexes  85 years and over           249907       2150131
# 18       Male           All Ages           539611       3963382
# 19       Male       Under 1 year              132         23025
# 20       Male         0-17 years              502         43340
# 21       Male          1-4 years               59          4388
# 22       Male         5-14 years              156          7335
# 23       Male        15-24 years             1506         58509
# 24       Male        18-29 years             3678        102666
# 25       Male        25-34 years             6629        118633
# 26       Male        30-39 years            10932        141298
# 27       Male        35-44 years            16771        163263
# 28       Male        40-49 years            26469        199361
# 29       Male        45-54 years            41813        278733
# 30       Male        50-64 years           113886        784130
# 31       Male        55-64 years            88401        616909
# 32       Male        65-74 years           133217        892018
# 33       Male        75-84 years           141149        951762
# 34       Male  85 years and over           109778        848807
# 35     Female           All Ages           434671       3557168
# 36     Female       Under 1 year              110         18752
# 37     Female         0-17 years              431         30836
# 38     Female          1-4 years               54          3403
# 39     Female         5-14 years              140          5103
#
#                   11                             12                13  \
# 0   Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths
# 1             855731                         504882             10684
# 2                495                             28                28
# 3               1460                            252               204
# 4                293                             29                70
# 5                424                             96                82
# 6               2240                           1134                97
# 7               5161                           2890               170
# 8               8792                           5401               256
# 9              13974                           9074               352
# 10             21174                          14244               411
# 11             32595                          22631               553
# 12             51785                          35812               861
# 13            157306                         102271              2441
# 14            125293                          80374              1915
# 15            203723                         125727              2319
# 16            228850                         132899              2383
# 17            212662                         109138              2262
# 18            480017                         290373              5440
# 19               278                             17                14
# 20               798                            140               112
# 21               144                             14                45
# 22               232                             55                40
# 23              1340                            656                48
# 24              3120                           1717                92
# 25              5351                           3318               127
# 26              8567                           5671               173
# 27             12899                           8870               219
# 28             19923                          14238               308
# 29             32022                          22898               503
# 30             95077                          63096              1396
# 31             75219                          49034              1085
# 32            120830                          75101              1285
# 33            130434                          77038              1178
# 34            101268                          53372               896
# 35            375714                         214509              5244
# 36               217                             11                14
# 37               662                            112                92
# 38               149                             15                25
# 39               192                             41                42
#
#                                           14        15
# 0   Pneumonia, Influenza, or COVID-19 Deaths  Footnote
# 1                                    1334231       NaN
# 2                                        736       NaN
# 3                                       2342       NaN
# 4                                        447       NaN
# 5                                        705       NaN
# 6                                       3740       NaN
# 7                                       8470       NaN
# 8                                      14427       NaN
# 9                                      22829       NaN
# 10                                     34244       NaN
# 11                                     52407       NaN
# 12                                     81789       NaN
# 13                                    239728       NaN
# 14                                    189688       NaN
# 15                                    303859       NaN
# 16                                    349191       NaN
# 17                                    355405       NaN
# 18                                    733757       NaN
# 19                                       406       NaN
# 20                                      1270       NaN
# 21                                       234       NaN
# 22                                       372       NaN
# 23                                      2232       NaN
# 24                                      5162       NaN
# 25                                      8774       NaN
# 26                                     13981       NaN
# 27                                     20984       NaN
# 28                                     32402       NaN
# 29                                     51344       NaN
# 30                                    146989       NaN
# 31                                    115458       NaN
# 32                                    179978       NaN
# 33                                    195537       NaN
# 34                                    158438       NaN
# 35                                    600474       NaN
# 36                                       330       NaN
# 37                                      1072       NaN
# 38                                       213       NaN
# 39                                       333       NaN

# %%
death_condition = pd.read_csv('csv_files/cdc_death_counts_by_conditons.zip',header=0)
print(display(death_condition))
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       03/20/2022  01/01/2020  03/19/2022  By Total     NaN    NaN
# 1       03/20/2022  01/01/2020  03/19/2022  By Total     NaN    NaN
# 2       03/20/2022  01/01/2020  03/19/2022  By Total     NaN    NaN
# 3       03/20/2022  01/01/2020  03/19/2022  By Total     NaN    NaN
# 4       03/20/2022  01/01/2020  03/19/2022  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 385015  03/20/2022  11/01/2021  11/30/2021  By Month  2021.0   11.0
# 385016  03/20/2022  12/01/2021  12/31/2021  By Month  2021.0   12.0
# 385017  03/20/2022  01/01/2022  01/31/2022  By Month  2022.0    1.0
# 385018  03/20/2022  02/01/2022  02/28/2022  By Month  2022.0    2.0
# 385019  03/20/2022  03/01/2022  03/19/2022  By Month  2022.0    3.0
#
#                 State       Condition Group                Condition  \
# 0       United States  Respiratory diseases  Influenza and pneumonia
# 1       United States  Respiratory diseases  Influenza and pneumonia
# 2       United States  Respiratory diseases  Influenza and pneumonia
# 3       United States  Respiratory diseases  Influenza and pneumonia
# 4       United States  Respiratory diseases  Influenza and pneumonia
# ...               ...                   ...                      ...
# 385015    Puerto Rico              COVID-19                 COVID-19
# 385016    Puerto Rico              COVID-19                 COVID-19
# 385017    Puerto Rico              COVID-19                 COVID-19
# 385018    Puerto Rico              COVID-19                 COVID-19
# 385019    Puerto Rico              COVID-19                 COVID-19
#
#        ICD10_codes Age Group  COVID-19 Deaths  Number of Mentions Flag
# 0          J09-J18      0-24           1277.0              1334.0  NaN
# 1          J09-J18     25-34           5351.0              5551.0  NaN
# 2          J09-J18     35-44          14089.0             14644.0  NaN
# 3          J09-J18     45-54          35120.0             36444.0  NaN
# 4          J09-J18     55-64          76708.0             79386.0  NaN
# ...            ...       ...              ...                 ...  ...
# 385015        U071  All Ages             28.0                28.0  NaN
# 385016        U071  All Ages             51.0                51.0  NaN
# 385017        U071  All Ages              0.0                 0.0  NaN
# 385018        U071  All Ages              0.0                 0.0  NaN
# 385019        U071  All Ages              0.0                 0.0  NaN
#
# [385020 rows x 14 columns]
# None

# %% [markdown]
# ### Data Cleaning ###

# %%
sns.heatmap(death_condition.isnull(),yticklabels = False, cbar = False, cmap='viridis')
#As we can see on the plot below, not many of our columns (that we are currently using) contains a lot of null values.
#Except Covid 19-Deaths.. we should look further into that.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analysis ###

# %%
#Try to make an analysis of deaths of the different conditions over time
grouped_df_condition = pd.DataFrame(death_condition.groupby(['End Date','Condition'])["COVID-19 Deaths"].sum()).reset_index()

grouped_df_condition.index = grouped_df_condition.index.set_levels([pd.to_datetime(grouped_df_condition.index.levels[0]), grouped_df_condition.index.levels[1]])
grouped_df_condition.sort_index()


display(grouped_df_condition)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1863b2a3719d> in <module>
#       2 grouped_df_condition = pd.DataFrame(death_condition.groupby(['End Date','Condition'])["COVID-19 Deaths"].sum()).reset_index()
#       3
# ----> 4 grouped_df_condition.index = grouped_df_condition.index.set_levels([pd.to_datetime(grouped_df_condition.index.levels[0]), grouped_df_condition.index.levels[1]])
#       5 grouped_df_condition.sort_index()
#       6
#
# AttributeError: 'RangeIndex' object has no attribute 'set_levels'

# %%
sns.relplot(x="End Date", y="COVID-19 Deaths", hue="Condition",kind='line', data=grouped_df_condition,height=20, aspect=1)

# %%
grouped_df_age = pd.DataFrame(death_condition.groupby(['End Date','Age Group'])["COVID-19 Deaths"].sum())


grouped_df_age.index = grouped_df_age.index.set_levels([pd.to_datetime(grouped_df_age.index.levels[0]), grouped_df_age.index.levels[1]])
grouped_df_age.sort_index()


display(grouped_df_age)
# Out:
#                        COVID-19 Deaths
# End Date   Age Group
# 2020-01-31 0-24                    0.0
#            25-34                   0.0
#            35-44                   0.0
#            45-54                   5.0
#            55-64                   7.0
# ...                                ...
# 2021-12-31 65-74              968000.0
#            75-84              947346.0
#            85+                763251.0
#            All Ages          3902157.0
#            Not stated             13.0
#
# [270 rows x 1 columns]

# %%
sns.relplot(x="End Date", y="COVID-19 Deaths", hue="Age Group",kind='line', data=grouped_df_age,height=20, aspect=1.2)
#Thought:
#Need the fraction of people alive for these ages.. Since its less people alive at 85+.. so the count is weird
